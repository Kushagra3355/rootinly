# %%
# !pip install ultralytics roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 69.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 110.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 6.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typer
#     Found existing installation: typer 0.27.1
#     Uninstalling typer-0.27.1:
#       Successfully uninstalled typer-0.27.1
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="05j2AaNi6KvZ8ieRDR6e")
project = rf.workspace("kushagra-omar").project("rootinly_feature-ykarg")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to rootinly_feature-1 in yolov8:: 100%|██████████| 745/745 [00:00<00:00, 9117.36it/s]
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart#ultralytics-settings.

# %%
from ultralytics import YOLO

# Initialize the YOLOv8 Nano Segmentation model
model = YOLO('yolov8s-seg.pt')

# Execute the training pipeline
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=60,       # 50 is a good baseline to check for overfitting
    imgsz=640,       # Matches the Roboflow export resolution
    batch=16,        # Standard batch size for Colab T4 GPU
    project="Entire_Head_Segmentation",
    name="run_1"
)
# Out:
# ...
# Ultralytics 8.4.126 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
